# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Statistics
from scipy.stats import shapiro
import scipy.stats as stats

import warnings
warnings.filterwarnings('ignore')

# Automobile Dataset
file_path = 'cookie_cats.csv'
df = pd.read_csv(file_path)

# Adjust pd settings
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# <h1 style='text-align: center; color:#0d582b'>Customer Segmentation by RFM Analysis on Car Sales</h1>
#
# <h4>The goal of this project is to segment customers using RFM (Recency, Frequency, Monetary) analysis to gain insights into customer behavior.</h4>
#
# <div>Information about the datatable : </div>

# %%
df.head()
# Out:
#    userid  version  sum_gamerounds  retention_1  retention_7
# 0     116  gate_30               3        False        False
# 1     337  gate_30              38         True        False
# 2     377  gate_40             165         True        False
# 3     483  gate_40               1        False        False
# 4     488  gate_40             179         True         True

# %%
df.shape
# Out:
# (90189, 5)

# %%
df.isnull().sum()
# Out:
# userid            0
# version           0
# sum_gamerounds    0
# retention_1       0
# retention_7       0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90189 entries, 0 to 90188
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   userid          90189 non-null  int64
#  1   version         90189 non-null  object
#  2   sum_gamerounds  90189 non-null  int64
#  3   retention_1     90189 non-null  bool
#  4   retention_7     90189 non-null  bool
# dtypes: bool(2), int64(2), object(1)
# memory usage: 2.2+ MB

# %%
df.describe()
# Out:
#              userid  sum_gamerounds
# count  9.018900e+04    90189.000000
# mean   4.998412e+06       51.872457
# std    2.883286e+06      195.050858
# min    1.160000e+02        0.000000
# 25%    2.512230e+06        5.000000
# 50%    4.995815e+06       16.000000
# 75%    7.496452e+06       51.000000
# max    9.999861e+06    49854.000000

# %% [markdown]
# <h1 style='color: #0d582b;'>Information Table retention</h1>

# %% [markdown]
# <h3>Retention</h3>

# %%
# Retention rates
info_df = df.pivot_table(index='version', values=["retention_1","retention_7"], aggfunc=["count","mean"])
info_df.drop(("count", "retention_1"), axis=1, inplace=True)
info_df.columns = ["User_count","R1_Rate","R7_Rate"]


# Retention counts by version
g30r1 = df[(df["retention_1"] == True) & (df["version"] == "gate_30")]["userid"].count()
g30r7 = df[(df["retention_7"] == True) & (df["version"] == "gate_30")]["userid"].count()
g40r1 = df[(df["retention_1"] == True) & (df["version"] == "gate_40")]["userid"].count()
g40r7 = df[(df["retention_7"] == True) & (df["version"] == "gate_40")]["userid"].count()

info_df.loc["gate_30", "R1_Count"] = g30r1
info_df.loc["gate_30", "R7_Count"] = g30r7
info_df.loc["gate_40", "R1_Count"] = g40r1
info_df.loc["gate_40", "R7_Count"] = g40r7

# Formatting data type to integer 
info_df["R7_Count"] = info_df["R7_Count"].astype(int)
info_df["R1_Count"] = info_df["R1_Count"].astype(int)

info_df
# Out:
#          User_count   R1_Rate   R7_Rate  R1_Count  R7_Count
# version
# gate_30       44700  0.448188  0.190201     20034      8502
# gate_40       45489  0.442283  0.182000     20119      8279

# %% [markdown]
# <h3>Downloaded but Never Played</h3>

# %%
n_30 = df[(df["sum_gamerounds"] == 0) & (df["version"] == "gate_30")]["userid"].count()
n_40 = df[(df["sum_gamerounds"] == 0) & (df["version"] == "gate_40")]["userid"].count()


info_df.loc["gate_30", "Never_played"] = n_30
info_df.loc["gate_40", "Never_played"] = n_40

info_df["Never_played"] = info_df["Never_played"].astype(int)
info_df
# Out:
#          User_count   R1_Rate   R7_Rate  R1_Count  R7_Count  Never_played
# version
# gate_30       44700  0.448188  0.190201     20034      8502          1937
# gate_40       45489  0.442283  0.182000     20119      8279          2057

# %% [markdown]
# <h1 style='color: #0d582b;'>Data Visualisation</h1>

# %%
# Set the figure size
plt.figure(figsize=(6, 6))

# Second bar plot for User_count
barplot = sns.barplot(data=info_df, x=info_df.index, y='User_count', color='orange', alpha=0.7, label='User Count')
# First bar plot for Never_played
barplot = sns.barplot(data=info_df, x=info_df.index, y='Never_played', color='blue', alpha=0.7, label='Never Played')

# Adding labels to the bars
for container in barplot.containers:
    barplot.bar_label(container, fontsize=10)


# Add legend, labels, and title
plt.legend()
plt.xlabel('Versions')
plt.ylabel('Count')
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.title('Comparison of Players that never Played and Total Player Count')
plt.legend(bbox_to_anchor=(0.5, -0.15), loc='upper center', ncol=2)

plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.suptitle('Retention Rates', fontsize=14)

plt.subplot(1, 2, 1)  

barplot1 = sns.barplot(data=info_df, x=info_df.index, y='User_count', color='orange', alpha=0.7, label='User Count')
barplot1 = sns.barplot(data=info_df, x=info_df.index, y='R1_Count', color='blue', alpha=1, label='1 Day Retention')


for container in barplot1.containers:
    barplot1.bar_label(container, fontsize=10)


plt.legend()
plt.xlabel('Versions')
plt.ylabel('Count')
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.title('1 Day Retention') 
plt.legend(bbox_to_anchor=(0.5, -0.15), loc='upper center', ncol=2)


plt.subplot(1, 2, 2)  
barplot2 = sns.barplot(data=info_df, x=info_df.index, y='User_count', color='orange', alpha=0.7, label='User Count')
barplot2 = sns.barplot(data=info_df, x=info_df.index, y='R7_Count', color='blue', alpha=0.7, label='7 Day Retention')


for container in barplot2.containers:
    barplot2.bar_label(container, fontsize=10)


plt.legend()
plt.xlabel('Versions')
plt.ylabel('Count')
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.title('7 Day Retention')  
plt.legend(bbox_to_anchor=(0.5, -0.15), loc='upper center', ncol=2)

plt.tight_layout()
plt.show()

# %%
# Determining Retention class
df['Retention_Class'] = df.apply(lambda row: 'No Retention' if not row['retention_1'] and not row['retention_7'] else
                                   'Retained only on Day 1' if row['retention_1'] and not row['retention_7'] else
                                   'Retained on Day 1 and Day 7' if row['retention_1'] and row['retention_7'] else 
                                   "Didn't Retained on Day 1, Retained After Day 7", axis=1).astype(str)
# Out:
# 90189

# %%
plt.figure(figsize=(10, 5))


grouped_df = df.groupby(["version", "Retention_Class"])["sum_gamerounds"].mean().reset_index()
grouped_df = grouped_df.sort_values(by="sum_gamerounds", ascending=True)


barplot = sns.barplot(data=grouped_df,
                      x="version",
                      y="sum_gamerounds",
                      hue="Retention_Class")


for container in barplot.containers:
    barplot.bar_label(container, fontsize=10)



plt.legend(title="Retention Class", bbox_to_anchor=(0.5, -0.15), loc='upper center')

plt.xlabel("Version")
plt.ylabel("Mean of Sum Gamerounds")
plt.title("Mean of Sum Gamerounds by Version and Retention Class")
plt.show()

# %%
quantile_80 = df["sum_gamerounds"].quantile(0.8)
fifty_rounds = df[df["sum_gamerounds"] < quantile_80]


g = sns.displot(data=fifty_rounds, x="sum_gamerounds", kind="hist", hue="version", height=8, aspect=1.5)


plt.show()

# %% [markdown]
# <h1 style='color: #0d582b;'>A/B Testing</h1>

# %% [markdown]
# <h3>Check Normality (Shapiro - Wilk Test)</h3>

# %%
A = df[df["version"] == "gate_30"]["sum_gamerounds"]
B = df[df["version"] == "gate_40"]["sum_gamerounds"]

# %%
#H0 Distribution is Normal
#H1 Distribution is not Normal

normalTestA = shapiro(A)

alpha = 0.05

# Printing the results
if normalTestA.pvalue < alpha:
    print(f"p value ({normalTestA.pvalue}) is below alpha value ({alpha}) therefore we reject the null hypothesis for group A (gate_30)")
else:
    print(f"p value ({normalTestA.pvalue}) is above alpha value ({alpha}) therefore we fail to reject the null hypothesis for group A (gate_30)")
# Out:
# p value (0.0) is below alpha value (0.05) therefore we reject the null hypothesis for group A (gate_30)

# %%
#H0 Distribution is Normal
#H1 Distribution is not Normal

normalTestB = shapiro(B)

alpha = 0.05

# Printing the results
if normalTestB.pvalue < alpha:
    print(f"p value ({normalTestB.pvalue}) is below alpha value ({alpha}) therefore we reject the null hypothesis for group B (gate_40)")
else:
    print(f"p value ({normalTestB.pvalue}) is above alpha value ({alpha}) therefore we fail to reject the null hypothesis for group B (gate_40)")
# Out:
# p value (0.0) is below alpha value (0.05) therefore we reject the null hypothesis for group B (gate_30)

# %%
# H0:  The variances of the groups or samples are equal. (Homogeneity)
# H1:  The variances of the groups or samples are not equal. (Heterogeneous)

leveneTest = stats.levene(A,B)

alpha = 0.05

if leveneTest.pvalue < alpha:
    print(f"p value ({leveneTest.pvalue}) is below alpha value ({alpha}), therefore we reject the null hypothesis.")
else:
    print(f"p value ({leveneTest.pvalue}) is above alpha value ({alpha}), therefore we fail to reject the null hypothesis.")
# Out:
# p value (0.46694516772623273) is above alpha value (0.05), therefore we fail to reject the null hypothesis.

# %% [markdown]
# our data is not normal and homogeneous variances

# %%
#H0: The distributions of both groups are identical.
#H1: The distributions of the two groups are not identical.

mannWhitneyUTest = stats.mannwhitneyu(A, B)

alpha = 0.05

if mannWhitneyUTest.pvalue < alpha:
    print(f"p value ({mannWhitneyUTest.pvalue}) is below alpha value ({alpha}), therefore we reject the null hypothesis.")
else:
    print(f"p value ({mannWhitneyUTest.pvalue}) is above alpha value ({alpha}), therefore we fail to reject the null hypothesis.")
# Out:
# p value (0.05020880772044255) is above alpha value (0.05), therefore we fail to reject the null hypothesis.

# %% [markdown]
# <h1 style='color: red; text-align: center;'>General Recommendations</h1>
#         <ul>
#             <li>Data-Driven Personalization: Utilize data analytics to personalize communications and offers for each segment.</li>
#             <li>Cross-Selling and Up-Selling: Identify opportunities for cross-selling and up-selling based on customer purchase history.</li>
#             <li>Customer Feedback Loop: Regularly gather feedback to understand customer needs and improve services.</li>
#             <li>Retention Strategies: Implement a robust retention strategy that includes loyalty programs, regular engagement, and exceptional customer service.</li>
#             <li>Automation: Use marketing automation tools to streamline communication and offer delivery based on customer behavior.</li>
#         </ul>
#     </div>
